# %%
import pandas as pd
import csv
import os

# %% [markdown]
# <b> In this notebook, we are going to combine all the 4 years of Twitch Data and drop all the unnecessary columns.</b>

# %%
t_2016 = pd.read_csv("C:\\Users\\gugla\\Desktop\\Twitch_Data\\Raw_Data\\twitch_2016.csv")

# %%
# When removing all the columns together it was giving an error, so had to remove them separately.
t_2016 = t_2016.drop(['Unnamed: 0'],axis = 1)
t_2016 = t_2016.drop(['Unnamed: 0.1'],axis = 1)
t_2016 = t_2016.drop(['Unnamed: 1'],axis = 1) 
t_2016 = t_2016.drop(['Unnamed: 11'],axis = 1)

# %%
t_2016
# Out:
#                              Game  Watch time  Stream time  Peak viewers  \
# 0      Sid Meier's Civilization V   230325420      7540020         22764
# 1        American Truck Simulator   227861940      9681600         47163
# 2                    Guild Wars 2   225037680     15305280          6577
# 3                      Subnautica   224039700      5750340         32141
# 4                    Watch Dogs 2   221952420      3471900         60009
# ...                           ...         ...          ...           ...
# 14495               Mass Effect 3    21671280       238440         11309
# 14496          Resident Evil Zero    21633120      1430820         27708
# 14497               Secret Hitler    21206100        29520         41675
# 14498               Slime Rancher    20490540       136560         37991
# 14499                    Splatoon    20019960       995400        128419
#
#        Peak channels  Streamers  Average viewers  Average channels  \
# ...

# %%
t_2017= pd.read_csv("C:\\Users\\gugla\\Desktop\\Twitch_Data\\Raw_Data\\twitch_2017.csv")

# %%
t_2017 = t_2017.drop(['Unnamed: 0'],axis = 1)
t_2017 = t_2017.drop(['Unnamed: 0.1'],axis = 1)
t_2017 = t_2017.drop(['Unnamed: 1'],axis = 1) 
t_2017 = t_2017.drop(['Unnamed: 11'],axis = 1)

# %%
t_2017
# Out:
#                                           Game  Watch time  Stream time  \
# 0                                    Fallout 4   380311440     46317300
# 1          Tom Clancy's Ghost Recon: Wildlands   361714800     23172060
# 2      The Legend of Zelda: A Link to the Past   356250240     12184980
# 3         The Legend of Zelda: Ocarina of Time   352184880      7480800
# 4                            They Are Billions   351079920      2830380
# ...                                        ...         ...          ...
# 14495                 Assassin's Creed Origins   416705280     11399160
# 14496                            Games + Demos   414610920      8187420
# 14497                                Outlast 2   410257920     12174660
# 14498                                     osu!   400830240     53728620
# 14499                             Mario Kart 8   397342380      8414700
#
#        Peak viewers  Peak channels  Streamers  Average viewers  \
# ...

# %%
t_2018 = pd.read_csv("C:\\Users\\gugla\\Desktop\\Twitch_Data\\Raw_Data\\twitch_2018.csv")

# %%
t_2018 = t_2018.drop(['Unnamed: 0'],axis = 1)
t_2018 = t_2018.drop(['Unnamed: 0.1'],axis = 1)
t_2018 = t_2018.drop(['Unnamed: 1'],axis = 1) 
t_2018 = t_2018.drop(['Unnamed: 11'],axis = 1)

# %%
t_2018
# Out:
#                                        Game  Watch time  Stream time  \
# 0                                  Artifact   547156380      7679280
# 1                           Ring Of Elysium   546117720     45019140
# 2                         World of Warships   545052120     31383420
# 3                         Age of Empires II   544093140      9658200
# 4      The Legend of Zelda: Ocarina of Time   543097980     13330980
# ...                                     ...         ...          ...
# 14495                Welcome to the Game II   569563200      2515080
# 14496                                Arma 3   568406460     43668060
# 14497              Summoners War: Sky Arena   566876100     12274320
# 14498                          No Man's Sky   555284820     25773480
# 14499                          Conan Exiles   547712580     28764360
#
#        Peak viewers  Peak channels  Streamers  Average viewers  \
# 0             67321           1590      12899             1041
# ...

# %%
t_2019 = pd.read_csv("C:\\Users\\gugla\\Desktop\\Twitch_Data\\Raw_Data\\twitch_2019.csv")

# %%
t_2019 = t_2019.drop(['Unnamed: 0'],axis = 1)
t_2019 = t_2019.drop(['Unnamed: 0.1'],axis = 1)
t_2019 = t_2019.drop(['Unnamed: 1'],axis = 1) 
t_2019 = t_2019.drop(['Unnamed: 11'],axis = 1)

# %%
t_2019
# Out:
#                                        Game  Watch time  Stream time  \
# 0                         They Are Billions   562559940      7158180
# 1                  The Witcher 3: Wild Hunt   557882880     39764640
# 2                            Slay the Spire   554713320     12541980
# 3                        Kingdom Hearts III   549841440     26626080
# 4         Halo: The Master Chief Collection   543847560     33798420
# ...                                     ...         ...          ...
# 14495               Super Smash Bros. Melee   581273400      7915380
# 14496  The Legend of Zelda: Ocarina of Time   575146800     20115180
# 14497                               Mordhau   567939180     18671820
# 14498             Total War: Three Kingdoms   566561040      7212180
# 14499                             Jump King   565418400      1760940
#
#        Peak viewers  Peak channels  Streamers  Average viewers  \
# 0             48479            156       8582             1070
# ...

# %%
t_16_17 = t_2016.merge(t_2017,how='outer')

# %%
t_16_17
# Out:
#                              Game  Watch time  Stream time  Peak viewers  \
# 0      Sid Meier's Civilization V   230325420      7540020         22764
# 1      Sid Meier's Civilization V   230325420      7540020         22764
# 2        American Truck Simulator   227861940      9681600         47163
# 3        American Truck Simulator   227861940      9681600         47163
# 4                    Guild Wars 2   225037680     15305280          6577
# ...                           ...         ...          ...           ...
# 28995    Assassin's Creed Origins   416705280     11399160         80844
# 28996               Games + Demos   414610920      8187420         86250
# 28997                   Outlast 2   410257920     12174660        212319
# 28998                        osu!   400830240     53728620         18701
# 28999                Mario Kart 8   397342380      8414700         59013
#
#        Peak channels  Streamers  Average viewers  Average channels  \
# ...

# %%
t_16_17_18 = t_16_17.merge(t_2018,how='outer')

# %%
t_16_17_18
# Out:
#                              Game  Watch time  Stream time  Peak viewers  \
# 0      Sid Meier's Civilization V   230325420      7540020         22764
# 1      Sid Meier's Civilization V   230325420      7540020         22764
# 2        American Truck Simulator   227861940      9681600         47163
# 3        American Truck Simulator   227861940      9681600         47163
# 4                    Guild Wars 2   225037680     15305280          6577
# ...                           ...         ...          ...           ...
# 43495      Welcome to the Game II   569563200      2515080        129007
# 43496                      Arma 3   568406460     43668060         24231
# 43497    Summoners War: Sky Arena   566876100     12274320         42720
# 43498                No Man's Sky   555284820     25773480        118853
# 43499                Conan Exiles   547712580     28764360         89655
#
#        Peak channels  Streamers  Average viewers  Average channels  \
# ...

# %%
twitch_final = t_16_17_18.merge(t_2019,how='outer')

# %%
twitch_final
# Out:
#                                        Game  Watch time  Stream time  \
# 0                Sid Meier's Civilization V   230325420      7540020
# 1                Sid Meier's Civilization V   230325420      7540020
# 2                  American Truck Simulator   227861940      9681600
# 3                  American Truck Simulator   227861940      9681600
# 4                              Guild Wars 2   225037680     15305280
# ...                                     ...         ...          ...
# 57995               Super Smash Bros. Melee   581273400      7915380
# 57996  The Legend of Zelda: Ocarina of Time   575146800     20115180
# 57997                               Mordhau   567939180     18671820
# 57998             Total War: Three Kingdoms   566561040      7212180
# 57999                             Jump King   565418400      1760940
#
#        Peak viewers  Peak channels  Streamers  Average viewers  \
# 0             22764             54      17212              437
# ...

# %% [markdown]
# <b> Renaming the columns</b>

# %%
twitch_final.rename(columns = {
    'Watch time': 'Watch_time',
    'Stream time': 'Stream_time',
    'Peak viewers': 'Peak_viewers',
    'Peak channels': 'Peak_channels',
    'Average viewers': 'Average_viewers',
    'Average channels': 'Average_channels',
    'Average viewer ratio': 'Average_viewer_ratio'
},inplace = True)

# %% [markdown]
# <b>Grouping the dataframe by Game and adding all the columns and sorting the dataframe by watch time so the most watched game comes on the top.</b>

# %%
twitch_final = twitch_final.groupby('Game').sum().sort_values(by='Watch_time',ascending=False).reset_index()

# %%
twitch_final
# Out:
#                                    Game    Watch_time  Stream_time  \
# 0                     League of Legends  193235523120   3573629520
# 1                              Fortnite  149623513560   9327850080
# 2                                Dota 2   88230167100    909440340
# 3      Counter-Strike: Global Offensive   79637110860   1674087780
# 4         PLAYERUNKNOWN'S BATTLEGROUNDS   74638243080   2566294320
# ...                                 ...           ...          ...
# 26040                       Corn Buster           240           60
# 26041                 Shakugan no Shana           240           60
# 26042                       Bit Planets           240           60
# 26043                 Crab Cakes Rescue           240           60
# 26044            Warlords: Call to Arms           240           60
#
#        Peak_viewers  Peak_channels  Streamers  Average_viewers  \
# 0           4545117          17511    2389081           483934
# ...

# %%
twitch_final.to_csv("twitch_final.csv")
